# %%
import torch
import pyro
import pyro.distributions as dist
import pyro.optim as optim 
from pyro.infer import EmpiricalMarginal, SVI, Trace_ELBO, JitTrace_ELBO
import pandas as pd
from torch.distributions import constraints
from pyro.infer.mcmc.api import MCMC
from pyro.infer.mcmc import NUTS
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from preprocessor import YelpData
from pyro.infer.autoguide import init_to_feasible

# %%
data_class = YelpData()
# data_class.process()
# data = torch.from_numpy(data_class.add_bias().astype(np.float32))
# ratings = torch.from_numpy(data_class.ratings.to_numpy().astype(np.float32))

# %%
# data_class.to_pickle(data, 'data')
# data_class.to_pickle(ratings, 'ratings')

# %%
data = data_class.load('data')/ 10000
ratings = data_class.load('ratings')
num_features = data.shape[1] - 1

# %%
import json
# load json file to dataframe
business = []
for line in open('./yelp_dataset/business.json', 'r'):
    business.append(json.loads(line))
bus_json = {"business":business}
df = pd.DataFrame(bus_json['business'])

# %%
def model(data, ratings):
#     betas = []

    #bias
#     betas.append(pyro.sample("beta_0", dist.Normal(0, 1)))
    #make one-hot vector length betas
    with pyro.plate("betas", num_features + 1):
        betas = pyro.sample("beta", dist.Gamma(1,1))
#     for i in range(num_feature):
#         betas.append(pyro.sample("beta_{}".format(i + 1), dist.Normal(0, 1)))

#     betas = torch.from_numpy(np.array(betas))
#     print(betas.dtype)
    lambda_ = torch.exp(torch.sum(betas * data))
#     import pdb
#     pdb.set_trace()
    with pyro.plate("ratings", ratings.shape[0]):
        y = pyro.sample("obs", dist.Poisson(lambda_), obs = ratings)
#     import pdb
#     pdb.set_trace()
    return y
# model(data, ratings)

# %%
def guide(data, ratings):
    alphas_0 = pyro.param('weights_loc', torch.ones(548),  constraint=constraints.positive)
    alphas_1 = pyro.param('weights_scale', torch.ones(548), constraint=constraints.positive)        
#     weights_loc = pyro.param('weights_loc', torch.randn(2))
#     weights_scale = pyro.param('weights_scale', torch.ones(2), constraint=constraints.positive)        

    with pyro.plate("betas", num_features + 1):
        betas = pyro.sample("beta", dist.Gamma(alphas_0, alphas_1))

# %%
# def guide(rating, rating_ns, popularity):
#     weights_loc = pyro.param('weights_loc', torch.randn(3))
#     weights_scale = pyro.param('weights_scale', torch.ones(3), constraint=constraints.positive)        
# #     weights_loc = pyro.param('weights_loc', torch.randn(2))
# #     weights_scale = pyro.param('weights_scale', torch.ones(2), constraint=constraints.positive)        

    
#     beta_0 = pyro.sample("beta_0", dist.Normal(weights_loc[0], weights_scale[0]))
#     beta_1 = pyro.sample("beta_1", dist.Normal(weights_loc[1], weights_scale[1]))
#     beta_2 = pyro.sample("beta_2", dist.Normal(weights_loc[2], weights_scale[2]))
#     labmda_ = torch.exp(beta_0 + beta_1 * rating + beta_2 * rating_ns)
# #     labmda_ = torch.exp(beta_0 + beta_1 * rating)

# guide = pyro.infer.autoguide.AutoDiagonalNormal(model, init_loc_fn=init_to_feasible)
# guide = pyro.infer.autoguide.AutoMultivariateNormal(model)

# %%
svi = SVI(model, 
          guide, 
          optim.Adam({"lr": .005}), 
          loss=JitTrace_ELBO(), 
          num_samples=1000)

pyro.clear_param_store()
epoch = 10000
for i in range(epoch):
    ELBO = svi.step(data, ratings)
    if i % 500 == 0:
        print(ELBO)
# Out:
# 15705455616.0
# 7840021.0
# 165630352.0
# 13975134.0
# 1177377.125
# 33034264.0
# 7142086.0
# 3409106.25
# 102896448.0
# 10036436.0
# 1249363.625
# 541185.8125
# 1207146.75
# 1307763.375
# 286059.0
# 845038.6875
# 302466.46875
# 2049273.625
# 104377.5234375
# 7573593.5

# %%
nuts_kernel = NUTS(model)

mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)
mcmc.run(data, ratings)

hmc_samples = {k: v.detach().cpu().numpy() for k, v in mcmc.get_samples().items()}
# Out:
# warmup:   4%|▍         | 54/1200 [01:12<2:30:59,  7.90s/it, step size=2.90e-02, acc. prob=0.965]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-0799382063f6> in <module>
#       2
#       3 mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)
# ----> 4 mcmc.run(data, ratings)
#       5
#       6 hmc_samples = {k: v.detach().cpu().numpy() for k, v in mcmc.get_samples().items()}
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     336         z_flat_acc = [[] for _ in range(self.num_chains)]
#     337         with pyro.validation_enabled(not self.disable_validation):
# --> 338             for x, chain_id in self.sampler.run(*args, **kwargs):
#     339                 if num_samples[chain_id] == 0:
#     340                     num_samples[chain_id] += 1
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     155         hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
#     156         for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, hook_w_logging,
# --> 157                                    *args, **kwargs):
#     158             yield sample, 0  # sample, chain_id (default=0)
#     159         progress_bar.close()
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in _gen_samples(kernel, warmup_steps, num_samples, hook, *args, **kwargs)
#     108     yield {k: v.shape for k, v in params.items()}
#     109     for i in range(warmup_steps):
# --> 110         params = kernel.sample(params)
#     111         hook(kernel, params, 'warmup', i)
#     112     for i in range(num_samples):
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in sample(self, params)
#     338                 if direction == 1:  # go to the right, start from the right leaf of current tree
#     339                     new_tree = self._build_tree(z_right, r_right, z_right_grads, log_slice,
# --> 340                                                 direction, tree_depth, energy_current)
#     341                     # update leaf for the next doubling process
#     342                     z_right = new_tree.z_right
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     221             z_grads = half_tree.z_left_grads
#     222         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 223                                            direction, tree_depth-1, energy_current)
#     224
#     225         if self.use_multinomial_sampling:
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     200         # build the first half of tree
#     201         half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 202                                      direction, tree_depth-1, energy_current)
#     203         z_proposal = half_tree.z_proposal
#     204         z_proposal_pe = half_tree.z_proposal_pe
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     200         # build the first half of tree
#     201         half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 202                                      direction, tree_depth-1, energy_current)
#     203         z_proposal = half_tree.z_proposal
#     204         z_proposal_pe = half_tree.z_proposal_pe
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     221             z_grads = half_tree.z_left_grads
#     222         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 223                                            direction, tree_depth-1, energy_current)
#     224
#     225         if self.use_multinomial_sampling:
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     221             z_grads = half_tree.z_left_grads
#     222         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 223                                            direction, tree_depth-1, energy_current)
#     224
#     225         if self.use_multinomial_sampling:
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     221             z_grads = half_tree.z_left_grads
#     222         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 223                                            direction, tree_depth-1, energy_current)
#     224
#     225         if self.use_multinomial_sampling:
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     196     def _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current):
#     197         if tree_depth == 0:
# --> 198             return self._build_basetree(z, r, z_grads, log_slice, direction, energy_current)
#     199
#     200         # build the first half of tree
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#     172         step_size = self.step_size if direction == 1 else -self.step_size
#     173         z_new, r_new, z_grads, potential_energy = velocity_verlet(
# --> 174             z, r, self.potential_fn, self.inverse_mass_matrix, step_size, z_grads=z_grads)
#     175         r_new_flat = torch.cat([r_new[site_name].reshape(-1) for site_name in sorted(r_new)])
#     176         energy_new = potential_energy + self._kinetic_energy(r_new)
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/ops/integrator.py in velocity_verlet(z, r, potential_fn, inverse_mass_matrix, step_size, num_steps, z_grads)
#      32                                                                         inverse_mass_matrix,
#      33                                                                         step_size,
# ---> 34                                                                         z_grads)
#      35     return z_next, r_next, z_grads, potential_energy
#      36
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/ops/integrator.py in _single_step_verlet(z, r, potential_fn, inverse_mass_matrix, step_size, z_grads)
#      50         z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
#      51
# ---> 52     z_grads, potential_energy = potential_grad(potential_fn, z)
#      53     for site_name in r:
#      54         r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/ops/integrator.py in potential_grad(potential_fn, z)
#      72         node.requires_grad_(True)
#      73     try:
# ---> 74         potential_energy = potential_fn(z)
#      75     # deal with singular matrices
#      76     except RuntimeError as e:
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/infer/mcmc/util.py in _potential_fn(self, params)
#     256         cond_model = poutine.condition(self.model, params_constrained)
#     257         model_trace = poutine.trace(cond_model).get_trace(*self.model_args,
# --> 258                                                           **self.model_kwargs)
#     259         log_joint = self.trace_prob_evaluator.log_prob(model_trace)
#     260         for name, t in self.transforms.items():
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/poutine/trace_messenger.py in get_trace(self, *args, **kwargs)
#     161         Calls this poutine and returns its trace instead of the function's return value.
#     162         """
# --> 163         self(*args, **kwargs)
#     164         return self.msngr.get_trace()
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     141                                       args=args, kwargs=kwargs)
#     142             try:
# --> 143                 ret = self.fn(*args, **kwargs)
#     144             except (ValueError, RuntimeError):
#     145                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#       6 def _context_wrap(context, fn, *args, **kwargs):
#       7     with context:
# ----> 8         return fn(*args, **kwargs)
#       9
#      10
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#       6 def _context_wrap(context, fn, *args, **kwargs):
#       7     with context:
# ----> 8         return fn(*args, **kwargs)
#       9
#      10
#
# ~/anaconda3/envs/pp/lib/python3.7/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#       6 def _context_wrap(context, fn, *args, **kwargs):
#       7     with context:
# ----> 8         return fn(*args, **kwargs)
#       9
#      10
#
# <ipython-input-47-65e98fa03ba6> in model(data, ratings)
#      12 #     betas = torch.from_numpy(np.array(betas))
#      13 #     print(betas.dtype)
# ---> 14     lambda_ = torch.exp(torch.sum(betas * data))
#      15 #     import pdb
#      16 #     pdb.set_trace()
#
# KeyboardInterrupt:

# %%
# Utility function to print latent sites' quantile information.
def summary(samples):
    site_stats = {}
    for site_name, values in samples.items():
        marginal_site = pd.DataFrame(values)
        describe = marginal_site.describe(percentiles=[.05, 0.25, 0.5, 0.75, 0.95]).transpose()
        site_stats[site_name] = describe[["mean", "std", "5%", "25%", "50%", "75%", "95%"]]
    return site_stats

# %%
svi_diagnorm_posterior = svi.run(data, ratings)
sites = ["beta"]

svi_samples = {site: EmpiricalMarginal(svi_diagnorm_posterior, sites=site)
                     .enumerate_support().detach().cpu().numpy()
               for site in sites}
for site, values in summary(svi_samples).items():
    print("Site: {}".format(site))
    print(values, "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-c65c50a91d15> in <module>
#       5                      .enumerate_support().detach().cpu().numpy()
#       6                for site in sites}
# ----> 7 for site, values in summary(svi_samples).items():
#       8     print("Site: {}".format(site))
#       9     print(values, "\n")
#
# NameError: name 'summary' is not defined

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
fig.suptitle("Posterior Distribution", fontsize=16)
for i, ax in enumerate(axs.reshape(-1)):
    try:
        site = sites[i]
        sns.distplot(hmc_samples[site], ax=ax, label="HMC")        
        sns.distplot(svi_samples[site], ax=ax, label="SVI")
        ax.set_title(site)
    except:
        pass
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right');

# %%
# #MLE

# #variables
# MLE_thetas = torch.ones(train_data.shape[1] - 1, requires_grad = True)
# def neg_log_likelihood(x,y):
#     theta_times_x = MLE_thetas * x
#     log_likelihood = torch.sum(y * theta_times_x - torch.exp(theta_times_x))
#     return -log_likelihood

# def get_MLE(x, y):
#     epoch = 10000
#     optimizer = torch.optim.Adam([MLE_thetas])
#     for i in range(epoch):

#         optimizer.zero_grad()
#         target = neg_log_likelihood(x,y)
#         target.backward()
#         optimizer.step()

# get_MLE(train_data[:,:2],train_data[:,2:])

# %%
MLE_thetas

# %%
#MLE

#variables
MLE_thetas = torch.ones([548,1], requires_grad = True, dtype = torch.float32)
def neg_log_likelihood(x,y):
#     import pdb
#     pdb.set_trace()
    theta_times_x = torch.matmul(x, MLE_thetas)


    log_likelihood = torch.matmul(y, theta_times_x) + torch.sum(torch.exp(theta_times_x))
#     torch.sum(y * theta_times_x - torch.exp(theta_times_x))
    return -log_likelihood

def get_MLE(x, y):
    epoch = 1000
    optimizer = torch.optim.Adam([MLE_thetas])
    for i in range(epoch):

        optimizer.zero_grad()
        target = neg_log_likelihood(x,y)
#         print(target)
        target.backward()
        optimizer.step()

get_MLE(data, ratings)

# %%
MLE_thetas
# Out:
# tensor([[3.5136],
#         [4.2317],
#         [3.7128],
#         [2.7420],
#         [1.2363],
#         [4.0657],
#         [4.3124],
#         [3.5248],
#         [4.0266],
#         [1.2363],
#         [3.0732],
#         [3.2069],
#         [3.5548],
#         [1.2363],
#         [3.9610],
#         [4.2634],
#         [4.3900],
#         [3.5367],
#         [4.2208],
#         [4.1062],
#         [4.2268],
#         [2.2122],
#         [4.3321],
#         [3.9244],
#         [3.9843],
#         [4.3715],
#         [3.9043],
#         [4.1201],
#         [2.2122],
#         [3.2042],
#         [3.0741],
#         [4.5127],
#         [3.0742],
#         [4.0018],
#         [3.3578],
#         [4.1247],
#         [3.5959],
#         [4.2773],
#         [4.3532],
#         [4.1354],
#         [1.2363],
#         [2.3087],
#         [2.3087],
#         [4.1038],
#         [4.0225],
#         [3.9273],
#         [4.3853],
#         [3.9795],
#         [3.9377],
#         [3.3540],
#         [3.1862],
#         [3.8257],
#         [2.7416],
#         [4.2225],
#         [2.7477],
#         [3.6237],
#         [4.5200],
#         [4.2299],
#         [1.2363],
#         [3.7014],
#         [4.1780],
#         [4.1721],
#         [1.2363],
#         [4.4213],
#         [3.7892],
#         [3.2070],
#         [4.2970],
#         [4.2223],
#         [3.8379],
#         [3.9929],
#         [4.2683],
#         [3.9755],
#         [4.2758],
#         [4.2649],
#         [4.1171],
#         [4.3804],
#         [3.4015],
#         [2.2122],
#         [4.1368],
#         [3.1378],
#         [2.3084],
#         [4.1519],
#         [4.0646],
#         [1.2363],
#         [3.9871],
#         [4.1291],
#         [3.9365],
#         [4.0811],
#         [3.9921],
#         [3.9921],
#         [3.7405],
#         [2.2122],
#         [3.9408],
#         [4.2773],
#         [2.2122],
#         [3.2981],
#         [3.6763],
#         [3.9691],
#         [1.2363],
#         [4.2213],
#         [2.2122],
#         [4.4035],
#         [3.3359],
#         [1.2363],
#         [4.0653],
#         [3.8607],
#         [3.9876],
#         [3.5908],
#         [2.7394],
#         [3.8760],
#         [3.9945],
#         [4.4410],
#         [4.2773],
#         [4.2315],
#         [3.0741],
#         [2.3085],
#         [2.3087],
#         [3.8449],
#         [2.2122],
#         [3.9977],
#         [3.0345],
#         [3.6764],
#         [4.3770],
#         [3.5999],
#         [4.0573],
#         [3.4804],
#         [3.9921],
#         [4.1656],
#         [4.0764],
#         [4.1988],
#         [4.0803],
#         [4.1645],
#         [3.7333],
#         [4.2649],
#         [3.2035],
#         [4.0594],
#         [3.1102],
#         [4.0286],
#         [4.1054],
#         [4.2127],
#         [4.4103],
#         [4.1748],
#         [3.1653],
#         [3.9403],
#         [4.3563],
#         [3.9655],
#         [4.1916],
#         [3.6842],
#         [3.9697],
#         [4.3157],
#         [3.9895],
#         [4.2970],
#         [3.6550],
#         [4.0745],
#         [1.2363],
#         [4.2721],
#         [3.7403],
#         [2.2122],
#         [2.2122],
#         [3.0206],
#         [3.8372],
#         [3.7813],
#         [3.3578],
#         [3.7347],
#         [3.5036],
#         [2.6761],
#         [3.0005],
#         [3.4696],
#         [3.1742],
#         [3.9929],
#         [4.4275],
#         [4.4415],
#         [4.0641],
#         [3.3240],
#         [1.2363],
#         [4.0672],
#         [4.0516],
#         [4.0885],
#         [4.3375],
#         [4.0831],
#         [4.0004],
#         [3.6743],
#         [4.3587],
#         [3.7463],
#         [2.7593],
#         [4.0567],
#         [2.3086],
#         [4.0192],
#         [3.6764],
#         [4.1842],
#         [4.2682],
#         [4.1148],
#         [3.9913],
#         [4.0293],
#         [4.3475],
#         [3.4800],
#         [4.1721],
#         [4.3622],
#         [3.5918],
#         [2.3081],
#         [4.0636],
#         [3.0741],
#         [4.3243],
#         [3.9325],
#         [2.9718],
#         [4.5138],
#         [3.4448],
#         [3.3213],
#         [1.2363],
#         [2.9528],
#         [4.0678],
#         [3.1420],
#         [3.6673],
#         [3.8729],
#         [4.2460],
#         [3.4263],
#         [4.3935],
#         [3.0575],
#         [3.8581],
#         [3.8407],
#         [3.5733],
#         [4.0406],
#         [3.8562],
#         [3.6764],
#         [3.3166],
#         [4.0393],
#         [4.3429],
#         [2.6761],
#         [4.0877],
#         [4.1766],
#         [4.1841],
#         [4.4335],
#         [4.2897],
#         [3.1649],
#         [3.0744],
#         [3.2915],
#         [4.4415],
#         [3.7427],
#         [1.2363],
#         [1.2363],
#         [3.0698],
#         [4.0510],
#         [4.3638],
#         [3.1518],
#         [3.9273],
#         [3.9004],
#         [4.0716],
#         [3.8712],
#         [3.9917],
#         [3.0150],
#         [1.2363],
#         [4.3713],
#         [4.3080],
#         [4.1712],
#         [2.3081],
#         [1.2363],
#         [3.9274],
#         [3.9409],
#         [3.9153],
#         [4.0834],
#         [3.0768],
#         [4.2555],
#         [3.0715],
#         [3.0047],
#         [4.0171],
#         [3.9890],
#         [1.2363],
#         [1.2363],
#         [3.9442],
#         [4.2710],
#         [2.2122],
#         [4.3432],
#         [3.6407],
#         [3.9550],
#         [4.1818],
#         [3.9348],
#         [1.2363],
#         [3.3293],
#         [3.3540],
#         [3.6255],
#         [4.4665],
#         [4.0770],
#         [4.3175],
#         [3.6395],
#         [4.2800],
#         [3.6172],
#         [3.5908],
#         [4.4023],
#         [4.2973],
#         [2.3082],
#         [2.2122],
#         [4.2551],
#         [4.2785],
#         [3.3578],
#         [4.1667],
#         [3.8647],
#         [4.1519],
#         [3.9030],
#         [3.2460],
#         [4.2766],
#         [3.7492],
#         [4.3821],
#         [4.3480],
#         [1.2363],
#         [4.0842],
#         [3.5908],
#         [4.0588],
#         [2.2122],
#         [4.3049],
#         [4.2016],
#         [3.6764],
#         [4.2831],
#         [3.6138],
#         [3.7741],
#         [4.4919],
#         [3.6584],
#         [3.5312],
#         [3.2340],
#         [4.2759],
#         [3.9767],
#         [2.7468],
#         [4.2300],
#         [4.2997],
#         [3.9521],
#         [2.7386],
#         [4.0900],
#         [2.3086],
#         [3.9837],
#         [4.5206],
#         [4.4665],
#         [4.2317],
#         [3.2449],
#         [3.7427],
#         [2.3083],
#         [3.5940],
#         [3.8479],
#         [3.4152],
#         [2.7396],
#         [1.2363],
#         [3.1381],
#         [4.2755],
#         [3.9161],
#         [1.2363],
#         [3.8027],
#         [3.8379],
#         [3.9940],
#         [4.1712],
#         [1.2363],
#         [3.9342],
#         [4.4035],
#         [3.2065],
#         [4.2773],
#         [3.9153],
#         [1.2363],
#         [3.4729],
#         [4.0016],
#         [3.9909],
#         [1.2363],
#         [3.6064],
#         [4.1846],
#         [3.0744],
#         [3.0706],
#         [4.1269],
#         [3.2516],
#         [3.5846],
#         [3.9565],
#         [3.6002],
#         [3.0706],
#         [3.8327],
#         [3.6764],
#         [4.3618],
#         [3.8975],
#         [2.7522],
#         [4.2208],
#         [4.4924],
#         [2.3079],
#         [2.3081],
#         [1.2363],
#         [3.9929],
#         [4.4141],
#         [3.4719],
#         [2.3087],
#         [3.2060],
#         [4.1931],
#         [4.0651],
#         [3.6236],
#         [3.2449],
#         [4.1886],
#         [4.0286],
#         [3.9569],
#         [4.3699],
#         [4.1721],
#         [3.6749],
#         [3.7347],
#         [3.8673],
#         [4.2390],
#         [4.0715],
#         [4.3617],
#         [4.1258],
#         [4.4038],
#         [3.9929],
#         [3.7361],
#         [1.2363],
#         [4.2649],
#         [4.0920],
#         [3.1410],
#         [4.1558],
#         [3.5455],
#         [4.0798],
#         [3.7326],
#         [3.7515],
#         [3.0739],
#         [4.3984],
#         [4.3507],
#         [3.7339],
#         [3.6271],
#         [1.2363],
#         [3.7865],
#         [4.4674],
#         [3.8379],
#         [3.8375],
#         [4.0834],
#         [4.3194],
#         [4.1407],
#         [3.2979],
#         [3.5352],
#         [4.1225],
#         [3.5836],
#         [4.0192],
#         [4.3175],
#         [1.2363],
#         [4.1028],
#         [4.2841],
#         [2.7584],
#         [2.9856],
#         [2.2122],
#         [4.0601],
#         [3.1469],
#         [4.1614],
#         [4.3431],
#         [3.0137],
#         [3.7463],
#         [3.9190],
#         [1.2363],
#         [3.5658],
#         [4.3852],
#         [4.4053],
#         [1.2363],
#         [4.1946],
#         [4.1341],
#         [3.9921],
#         [3.8306],
#         [4.1153],
#         [4.0185],
#         [4.3093],
#         [4.3925],
#         [3.6319],
#         [3.5061],
#         [3.6911],
#         [3.9847],
#         [4.0623],
#         [4.0348],
#         [3.5724],
#         [4.1179],
#         [4.2501],
#         [3.1755],
#         [4.2314],
#         [3.5888],
#         [3.9921],
#         [3.9118],
#         [1.2363],
#         [4.2946],
#         [4.2645],
#         [1.2363],
#         [4.2773],
#         [3.6171],
#         [3.3943],
#         [4.0761],
#         [3.6310],
#         [3.1606],
#         [3.8379],
#         [4.2970],
#         [3.8647],
#         [3.9624],
#         [4.0041],
#         [4.0879],
#         [3.6764],
#         [3.6754],
#         [3.0744],
#         [4.1150],
#         [1.2363],
#         [3.5891],
#         [3.6764],
#         [4.2649],
#         [2.2122],
#         [4.4186],
#         [3.8861],
#         [4.2410],
#         [1.2363],
#         [4.2679],
#         [2.7575],
#         [4.2570],
#         [3.1725],
#         [4.1805],
#         [3.8347],
#         [4.1783],
#         [1.2363],
#         [3.6764],
#         [2.7584],
#         [4.3040],
#         [3.0963],
#         [3.7785],
#         [3.7250],
#         [4.1852],
#         [4.3187],
#         [4.2876],
#         [4.1538],
#         [4.1231],
#         [2.7382],
#         [3.9408],
#         [3.9289],
#         [4.1938],
#         [2.3081],
#         [4.4025],
#         [4.2773],
#         [4.2773],
#         [2.3086],
#         [4.2758],
#         [4.4388],
#         [4.0868],
#         [4.0570],
#         [3.8373],
#         [1.2363],
#         [4.0786],
#         [4.3270],
#         [2.2122],
#         [4.0091],
#         [3.8385],
#         [3.8013],
#         [3.3712],
#         [4.0532],
#         [4.3535],
#         [3.6170],
#         [4.2522],
#         [4.2206],
#         [4.1247],
#         [3.4630],
#         [1.2363]], requires_grad=True)
